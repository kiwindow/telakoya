# %% [markdown]
# <a href="https://colab.research.google.com/github/kiwindow/telakoya/blob/main/%E6%BC%94%E7%BF%9220220802.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **■　よくわかる寺子屋セミナー　第2回　データの読み込みと書き出し**

# %%
# 数値計算
1+1
# Out:
# 2

# %%
# かけ算は * を使う
2 * 4
# Out:
# 8

# %% [markdown]
# # 0. ドライブにマウント

# %%
# 今自分はどこにいるか
# !pwd
# Out:
# /content

# %%
# current directoryに何があるか
# !ls
# Out:
# drive  sample_data

# %%
# 今自分はなにをしているか
# !cat /etc/os-release
# Out:
# NAME="Ubuntu"
# VERSION="18.04.5 LTS (Bionic Beaver)"
# ID=ubuntu
# ID_LIKE=debian
# PRETTY_NAME="Ubuntu 18.04.5 LTS"
# VERSION_ID="18.04"
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# VERSION_CODENAME=bionic
# UBUNTU_CODENAME=bionic

# %% [markdown]
# # 1. 環境設定

# %%
# Libraryの読み込み
import numpy as np
import pandas as pd

# %%
# Excelを入出力するためのmoduleのインストール
# !pip install openpyxl
# !pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # 2. データの入出力

# %%
# csvファイルの読み込み(入力)
df = pd.read_csv('/content/drive/MyDrive/Telakoya/data/data.csv')

# %%
# ファイルの書き出し(出力)
df.to_csv('/content/drive/MyDrive/Telakoya/result/data.csv')

# %%
# encodingのエラーへの対処
df = pd.read_csv('/content/drive/MyDrive/Telakoya/data/sample.csv', encoding = 'unicode_escape')

# %% [markdown]
# # 3. メソッドの演習

# %%
# 単にDataFrameを出力させてみる
df
# Out:
#             ID factor1 factor2 factor3   factor4 factor5   factor6 factor7  \
# 0          ID1     NaN     NaN       A       NaN     NaN  1.241863       B
# 1          ID2       C       Z       Z  0.283582       A  0.243880       Z
# 2          ID3       A       A       C  3.175930       C  4.365006       A
# 3          ID4       A       Z       A  1.566577       A  2.983811       C
# 4          ID5       C       Z     NaN  0.464134       Z  2.191147     NaN
# ...        ...     ...     ...     ...       ...     ...       ...     ...
# 14995  ID14996       B       Z     NaN  2.197228     NaN  4.384694       C
# 14996  ID14997       A       C       A  4.077054       Z  0.445390       C
# 14997  ID14998       A       C       Z  1.407224       B  2.360011       B
# 14998  ID14999     NaN     NaN       Z       NaN       A  4.059424     NaN
# 14999  ID15000       A       B       A  4.072493       A  4.335164       C
#
# ...

# %%
# 最初から20行のデータの表示
df.head(20)
# Out:
#       ID factor1 factor2 factor3   factor4 factor5   factor6 factor7 factor8  \
# 0    ID1     NaN     NaN       A       NaN     NaN  1.241863       B     NaN
# 1    ID2       C       Z       Z  0.283582       A  0.243880       Z       A
# 2    ID3       A       A       C  3.175930       C  4.365006       A       C
# 3    ID4       A       Z       A  1.566577       A  2.983811       C       Z
# 4    ID5       C       Z     NaN  0.464134       Z  2.191147     NaN       B
# 5    ID6       Z       Z       Z  4.096361       A  1.549590     NaN       B
# 6    ID7     NaN       B       Z  2.162318       A  1.356833       C       A
# 7    ID8       A       Z       Z  3.015889       B       NaN     NaN       C
# 8    ID9       A     NaN       A  4.764512       A       NaN       Z       A
# 9   ID10     NaN       Z       B  3.524959       B  0.063331       A       C
# 10  ID11       Z       B       C  1.270760       C  2.090642       Z       C
# ...

# %%
# 最後から5行のデータの表示
df.tail()
# Out:
#             ID factor1 factor2 factor3   factor4 factor5   factor6 factor7  \
# 14995  ID14996       B       Z     NaN  2.197228     NaN  4.384694       C
# 14996  ID14997       A       C       A  4.077054       Z  0.445390       C
# 14997  ID14998       A       C       Z  1.407224       B  2.360011       B
# 14998  ID14999     NaN     NaN       Z       NaN       A  4.059424     NaN
# 14999  ID15000       A       B       A  4.072493       A  4.335164       C
#
#       factor8   factor9  ...  factor141  factor142  factor143 factor144  \
# 14995       A       NaN  ...   2.588611   2.877683          B  4.781191
# 14996     NaN  2.824001  ...   0.779132   0.491730        NaN       NaN
# 14997       A  2.511333  ...   2.044176   2.511333          Z  3.706377
# 14998     NaN  2.878456  ...        NaN   4.732487          B       NaN
# 14999       C  3.738258  ...   2.143087   4.569763          B  1.045792
#
#       factor145  factor146 factor147 factor148  factor149  factor150
# ...

# %%
# データのタイプの確認
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# データの行と列の数の確認
df.shape
# Out:
# (15000, 151)

# %%
# データの情報
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Columns: 151 entries, ID to factor150
# dtypes: float64(75), object(76)
# memory usage: 17.3+ MB

# %%
# 容量が大きい場合
df.info(memory_usage = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Columns: 151 entries, ID to factor150
# dtypes: float64(75), object(76)
# memory usage: 66.1 MB

# %%
# 統計量の算出
df.describe()
# Out:
#             factor4       factor6       factor9      factor10      factor11  \
# count  1.254400e+04  12514.000000  12511.000000  12526.000000  12500.000000
# mean   2.488085e+00      2.507221      2.505893      2.520863      2.489419
# std    1.431048e+00      1.441092      1.448540      1.450967      1.448868
# min    1.910715e-07      0.000865      0.000003      0.000056      0.000709
# 25%    1.273875e+00      1.266502      1.236694      1.260030      1.229542
# 50%    2.474292e+00      2.486029      2.501443      2.525176      2.483807
# 75%    3.729182e+00      3.745544      3.772298      3.790788      3.743121
# max    4.999861e+00      4.999757      4.999873      4.999891      4.999961
#
#            factor12      factor15      factor18      factor19      factor20  \
# count  12524.000000  12465.000000  12545.000000  12506.000000  12494.000000
# mean       2.496008      2.516159      2.497037      2.525902      2.494576
# ...

# %%
# Pandasの表をNumpyの配列に変える
data = np.array(df)
data
# Out:
# array([['ID1', nan, nan, ..., 1.259221302423431, 0.7732870517547132,
#         1.0287363490062829],
#        ['ID2', 'C', 'Z', ..., 0.2210971394155301, 0.976043833946374,
#         2.9835332667906647],
#        ['ID3', 'A', 'A', ..., nan, 2.4348970290644747, 4.520744788336513],
#        ...,
#        ['ID14998', 'A', 'C', ..., 4.859076275035232, 4.93298949898281,
#         0.3916589553081202],
#        ['ID14999', nan, nan, ..., 1.3145171071184372, 2.407776775332024,
#         2.731232887542422],
#        ['ID15000', 'A', 'B', ..., 3.9455075723675535, 0.9572876312888434,
#         nan]], dtype=object)

# %%
# データのタイプの確認
type(data)
# Out:
# numpy.ndarray

# %%
# 表の1行目の項目名(key)の取得
keys = df.columns
keys
# Out:
# Index(['ID', 'factor1', 'factor2', 'factor3', 'factor4', 'factor5', 'factor6',
#        'factor7', 'factor8', 'factor9',
#        ...
#        'factor141', 'factor142', 'factor143', 'factor144', 'factor145',
#        'factor146', 'factor147', 'factor148', 'factor149', 'factor150'],
#       dtype='object', length=151)

# %%
# 表の項目名も含めてNumpyの配列をPandasの表に変換する
df = pd.DataFrame(data, columns = keys)
df
# Out:
#             ID factor1 factor2 factor3   factor4 factor5   factor6 factor7  \
# 0          ID1     NaN     NaN       A       NaN     NaN  1.241863       B
# 1          ID2       C       Z       Z  0.283582       A   0.24388       Z
# 2          ID3       A       A       C   3.17593       C  4.365006       A
# 3          ID4       A       Z       A  1.566577       A  2.983811       C
# 4          ID5       C       Z     NaN  0.464134       Z  2.191147     NaN
# ...        ...     ...     ...     ...       ...     ...       ...     ...
# 14995  ID14996       B       Z     NaN  2.197228     NaN  4.384694       C
# 14996  ID14997       A       C       A  4.077054       Z   0.44539       C
# 14997  ID14998       A       C       Z  1.407224       B  2.360011       B
# 14998  ID14999     NaN     NaN       Z       NaN       A  4.059424     NaN
# 14999  ID15000       A       B       A  4.072493       A  4.335164       C
#
# ...
